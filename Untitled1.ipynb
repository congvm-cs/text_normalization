# %%
import phonetics
import fuzzy
import cmudict
import eng_to_ipa as ipa
import re
from tqdm import tqdm_notebook
import subprocess

# %%
cmu_dict = dict(cmudict.dict())

# %%
keep_list = ["ʌ","ɑ","æ","e","ə","ɜ","ɪ","i","ɒ","ɔ","ʊ","u","aɪ","aʊ","eɪ","oʊ","ɔɪ","eə","ɪə","ʊə","b","d","f","g","h","j","k","l","m","n","ŋ","p","r","ɹ", "s","ʃ","t","tʃ","θ","ð","v","w","z","ʒ","dʒ"]

def preprocess(word):
    """Returns a string of words stripped of punctuation"""
    punct_str = '!"#$%&\'()*+,-./:;<=>/?@[\\]^_`{|}~«» '
    return word.strip(punct_str).lower()

def get_ipa(word, core='espeak'):
    word = preprocess(word)
#     print(word)
    
    if core == "espeak":
        cmd = "espeak {} --ipa=1".format(word)
        result = subprocess.run(cmd.split(), stdout=subprocess.PIPE)
        result = result.stdout.split()[0].decode('utf-8')
        print(result)
    else:
        result = ipa.convert(word)
    
    ret = ""
    for i in result:
        if (i in keep_list) or (i in consonant_list):
            ret += i
    return ret

def ipa_to_viet(ipa_form):
    ret_= ""
    curren_idx = 0
    while curren_idx < len(ipa_form):
        if ipa_form[curren_idx:curren_idx+2] in map_dict:
            ret_ += map_dict[ipa_form[curren_idx:curren_idx+2]]
            curren_idx += 2
        elif ipa_form[curren_idx] in map_dict:
            ret_ += map_dict[ipa_form[curren_idx]]
            curren_idx += 1
        else:
            ret_ += ipa_form[curren_idx]
            curren_idx += 1
    return ret_


def remove_spec_punc(word):
    ret_= []
    for i in result:
        tmp = ""
        for j in i:
            if j != spec_pun:
                tmp += j
        ret_.append(tmp)

# %%
def get_ipa_q(word, core='espeak'):
    word = preprocess(word)
    if core == "espeak":
        cmd = "espeak {} --ipa=1".format(word)
        result = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
        result = result.stdout.split()[0].decode('utf-8')
    else:
        result = ipa.convert(word)
    return result

# %%
ipa_chars = set()

# %%
words = "English is a West Germanic language that was first spoken in early medieval England and is now the third most widespread native language in the world after Standard Chinese and Spanish as well as the most widely spoken Germanic language Welcome to the WikiWikiWeb, also known as. A lot of people had their first wiki experience here. This community has been around since 1995 and consists of many people. We always accept newcomers with valuable contributions. If you haven't used a wiki before, be prepared for a bit of CultureShock. The usefulness of Wiki is in the freedom, simplicity, and power it offers."

# %%
words
# Out:
# "English is a West Germanic language that was first spoken in early medieval England and is now the third most widespread native language in the world after Standard Chinese and Spanish as well as the most widely spoken Germanic language Welcome to the WikiWikiWeb, also known as. A lot of people had their first wiki experience here. This community has been around since 1995 and consists of many people. We always accept newcomers with valuable contributions. If you haven't used a wiki before, be prepared for a bit of CultureShock. The usefulness of Wiki is in the freedom, simplicity, and power it offers."

# %%
words = preprocess(word=words).split(' ')

# %%
words
# Out:
# ['english',
#  'is',
#  'a',
#  'west',
#  'germanic',
#  'language',
#  'that',
#  'was',
#  'first',
#  'spoken',
#  'in',
#  'early',
#  'medieval',
#  'england',
#  'and',
#  'is',
#  'now',
#  'the',
#  'third',
#  'most',
#  'widespread',
#  'native',
#  'language',
#  'in',
#  'the',
#  'world',
#  'after',
#  'standard',
#  'chinese',
#  'and',
#  'spanish',
#  'as',
#  'well',
#  'as',
#  'the',
#  'most',
#  'widely',
#  'spoken',
#  'germanic',
#  'language',
#  'welcome',
#  'to',
#  'the',
#  'wikiwikiweb,',
#  'also',
#  'known',
#  'as.',
#  'a',
#  'lot',
#  'of',
#  'people',
#  'had',
#  'their',
#  'first',
#  'wiki',
#  'experience',
#  'here.',
#  'this',
#  'community',
#  'has',
#  'been',
#  'around',
#  'since',
#  '1995',
#  'and',
#  'consists',
#  'of',
#  'many',
#  'people.',
#  'we',
#  'always',
#  'accept',
#  'newcomers',
#  'with',
#  'valuable',
#  'contributions.',
#  'if',
#  'you',
#  "haven't",
#  'used',
#  'a',
#  'wiki',
#  'before,',
#  'be',
#  'prepared',
#  'for',
#  'a',
#  'bit',
#  'of',
#  'cultureshock.',
#  'the',
#  'usefulness',
#  'of',
#  'wiki',
#  'is',
#  'in',
#  'the',
#  'freedom,',
#  'simplicity,',
#  'and',
#  'power',
#  'it',
#  'offers']

# %%
import re
import os
import json
from eng_to_ipa import transcribe
import numpy as np
import unicodedata
import eng_to_ipa

# %%
eng_to_ipa.syllable_count('medieval')
# Out:
# 3

# %%
cmu_dict['spoken']
# Out:
# [['S', 'P', 'OW1', 'K', 'AH0', 'N']]

# %%
for idx, word in enumerate(words):
    cmd = "espeak {} --ipa=1".format(word)
    result = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
    result = result.stdout.read().decode('utf-8').split("\n")[0].split("_")
    
    ret = "".join([i for i in mapping(remove_spec_punc(result))])
    
    print(idx, word, remove_spec_punc(result), ret, ipa_to_viet(ret))
# Out:
# 0 in False
# 1 nɡ False
# 2 ɡl False
# 3 li False
# 4 is False
# 5 s False
# 0 english ['ɪ', 'ŋ', 'ɡ', 'l', 'ɪ', 'ʃ'] inɡlis ['i', 'n', 'ɡ', 'l', 'i', 's']
# 0 id False
# 1 d False
# 1 is ['ɪ', 'z'] id ['i', 'd']
# 0 ây False
# 1 y False
# 2 a ['eɪ'] ây ['â', 'y']
# 0 qu True
# 2 es False
# 3 st False
# 4 t False
# 3 west ['w', 'ɛ', 's', 't'] quest ['qu', 'e', 's', 't']
# 0 ch True
# 2 ơm False
# 3 ma False
# 4 an False
# 5 ni False
# 6 ic False
# 7 c False
# 4 germanic ['dʒ', 'ɜː', 'm', 'a', 'n', 'ɪ', 'k'] chơmanic ['ch', 'ơ', 'm', 'a', 'n', 'i', 'c']
# 0 la False
# 1 an False
# 2 nɡ False
# 3 ɡq False
# 4 qu True
# 6 ic False
# 7 ch True
# 5 language ['l', 'a', 'ŋ', 'ɡ', 'w', 'ɪ', 'dʒ'] lanɡquich ['l', 'a', 'n', 'ɡ', 'qu', 'i', 'ch']
# 0 đa False
# 1 at False
# 2 t False
# 6 that ['ð', 'a', 't'] đat ['đ', 'a', 't']
# 0 qu True
# 2 od False
# 3 d False
# 7 was ['w', 'ɒ', 'z'] quod ['qu', 'o', 'd']
# 0 ph True
# 2 ơs False
# 3 st False
# 4 t False
# 8 first ['f', 'ɜː', 's', 't'] phơst ['ph', 'ơ', 's', 't']
# 0 sp False
# 1 pâ False
# 2 âu False
# 3 uc False
# 4 cơ False
# 5 ơn False
# 6 n False
# 9 spoken ['s', 'p', 'əʊ', 'k', 'ə', 'n'] spâucơn ['s', 'p', 'â', 'u', 'c', 'ơ', 'n']
# 0 in False
# 1 n False
# 10 in ['ɪ', 'n'] in ['i', 'n']
# 0 ơl False
# 1 li False
# 2 i False
# 11 early ['ɜː', 'l', 'ɪ'] ơli ['ơ', 'l', 'i']
# 0 me False
# 1 eđ False
# 2 đi False
# 3 ii False
# 4 iv False
# 5 vồ False
# 6 ồ False
# 12 medieval ['m', 'ɛ', 'd', 'ɪ', '', 'iː', 'v', 'əl'] međiivồ ['m', 'e', 'đ', 'i', 'i', 'v', 'ồ']
# 0 in False
# 1 nɡ False
# 2 ɡl False
# 3 lơ False
# 4 ơn False
# 5 nđ False
# 6 đ False
# 13 england ['ɪ', 'ŋ', 'ɡ', 'l', 'ə', 'n', 'd'] inɡlơnđ ['i', 'n', 'ɡ', 'l', 'ơ', 'n', 'đ']
# 0 an False
# 1 nđ False
# 2 đ False
# 14 and ['a', 'n', 'd'] anđ ['a', 'n', 'đ']
# 0 id False
# 1 d False
# 15 is ['ɪ', 'z'] id ['i', 'd']
# 0 na False
# 1 ao False
# 2 o False
# 16 now ['n', 'aʊ'] nao ['n', 'a', 'o']
# 0 đơ False
# 1 ơ False
# 17 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 th True
# 2 ơđ False
# 3 đ False
# 18 third ['θ', 'ɜː', 'd'] thơđ ['th', 'ơ', 'đ']
# 0 mâ False
# 1 âu False
# 2 us False
# 3 st False
# 4 t False
# 19 most ['m', 'əʊ', 's', 't'] mâust ['m', 'â', 'u', 's', 't']
# 0 qu True
# 2 ai False
# 3 iđ False
# 4 đs False
# 5 sp False
# 6 pr False
# 7 re False
# 8 eđ False
# 9 đ False
# 20 widespread ['w', 'aɪ', 'd', 's', 'p', 'ɹ', 'ɛ', 'd'] quaiđspređ ['qu', 'a', 'i', 'đ', 's', 'p', 'r', 'e', 'đ']
# 0 nâ False
# 1 ây False
# 2 yt False
# 3 ti False
# 4 iv False
# 5 v False
# 21 native ['n', 'eɪ', 't', 'ɪ', 'v'] nâytiv ['n', 'â', 'y', 't', 'i', 'v']
# 0 la False
# 1 an False
# 2 nɡ False
# 3 ɡq False
# 4 qu True
# 6 ic False
# 7 ch True
# 22 language ['l', 'a', 'ŋ', 'ɡ', 'w', 'ɪ', 'dʒ'] lanɡquich ['l', 'a', 'n', 'ɡ', 'qu', 'i', 'ch']
# 0 in False
# 1 n False
# 23 in ['ɪ', 'n'] in ['i', 'n']
# 0 đơ False
# 1 ơ False
# 24 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 qu True
# 2 ơl False
# 3 lđ False
# 4 đ False
# 25 world ['w', 'ɜː', 'l', 'd'] quơlđ ['qu', 'ơ', 'l', 'đ']
# 0 ap False
# 1 ph True
# 3 tơ False
# 4 ơ False
# 26 after ['a', 'f', 't', 'ə'] aphtơ ['a', 'ph', 't', 'ơ']
# 0 st False
# 1 ta False
# 2 an False
# 3 nđ False
# 4 đơ False
# 5 ơđ False
# 6 đ False
# 27 standard ['s', 't', 'a', 'n', 'd', 'ə', 'd'] stanđơđ ['s', 't', 'a', 'n', 'đ', 'ơ', 'đ']
# 0 ch True
# 2 ai False
# 3 in False
# 4 ni False
# 5 id False
# 6 d False
# 28 chinese ['tʃ', 'aɪ', 'n', 'iː', 'z'] chainid ['ch', 'a', 'i', 'n', 'i', 'd']
# 0 an False
# 1 nđ False
# 2 đ False
# 29 and ['a', 'n', 'd'] anđ ['a', 'n', 'đ']
# 0 sp False
# 1 pa False
# 2 an False
# 3 ni False
# 4 is False
# 5 s False
# 30 spanish ['s', 'p', 'a', 'n', 'ɪ', 'ʃ'] spanis ['s', 'p', 'a', 'n', 'i', 's']
# 0 ad False
# 1 d False
# 31 as ['a', 'z'] ad ['a', 'd']
# 0 qu True
# 2 el False
# 3 l False
# 32 well ['w', 'ɛ', 'l'] quel ['qu', 'e', 'l']
# 0 ad False
# 1 d False
# 33 as ['a', 'z'] ad ['a', 'd']
# 0 đơ False
# 1 ơ False
# 34 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 mâ False
# 1 âu False
# 2 us False
# 3 st False
# 4 t False
# 35 most ['m', 'əʊ', 's', 't'] mâust ['m', 'â', 'u', 's', 't']
# 0 qu True
# 2 ai False
# 3 iđ False
# 4 đl False
# 5 li False
# 6 i False
# 36 widely ['w', 'aɪ', 'd', 'l', 'i'] quaiđli ['qu', 'a', 'i', 'đ', 'l', 'i']
# 0 sp False
# 1 pâ False
# 2 âu False
# 3 uc False
# 4 cơ False
# 5 ơn False
# 6 n False
# 37 spoken ['s', 'p', 'əʊ', 'k', 'ə', 'n'] spâucơn ['s', 'p', 'â', 'u', 'c', 'ơ', 'n']
# 0 ch True
# 2 ơm False
# 3 ma False
# 4 an False
# 5 ni False
# 6 ic False
# 7 c False
# 38 germanic ['dʒ', 'ɜː', 'm', 'a', 'n', 'ɪ', 'k'] chơmanic ['ch', 'ơ', 'm', 'a', 'n', 'i', 'c']
# 0 la False
# 1 an False
# 2 nɡ False
# 3 ɡq False
# 4 qu True
# 6 ic False
# 7 ch True
# 39 language ['l', 'a', 'ŋ', 'ɡ', 'w', 'ɪ', 'dʒ'] lanɡquich ['l', 'a', 'n', 'ɡ', 'qu', 'i', 'ch']
# 0 qu True
# 2 el False
# 3 lc False
# 4 câ False
# 5 âm False
# 6 m False
# 40 welcome ['w', 'ɛ', 'l', 'k', 'ʌ', 'm'] quelcâm ['qu', 'e', 'l', 'c', 'â', 'm']
# 0 tu False
# 1 u False
# 41 to ['t', 'uː'] tu ['t', 'u']
# 0 đơ False
# 1 ơ False
# 42 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 qu True
# 2 ic False
# 3 ci False
# 4 iq False
# 5 qu True
# 7 ic False
# 8 ci False
# 9 iq False
# 10 qu True
# 12 eb False
# 13 b False
# 43 wikiwikiweb, ['w', 'ɪ', 'k', 'i', 'w', 'ɪ', 'k', 'i', 'w', 'ɛ', 'b'] quiciquiciqueb ['qu', 'i', 'c', 'i', 'qu', 'i', 'c', 'i', 'qu', 'e', 'b']
# 0 ol False
# 1 ls False
# 2 sâ False
# 3 âu False
# 4 u False
# 44 also ['ɔː', 'l', 's', 'əʊ'] olsâu ['o', 'l', 's', 'â', 'u']
# 0 nâ False
# 1 âu False
# 2 un False
# 3 n False
# 45 known ['n', 'əʊ', 'n'] nâun ['n', 'â', 'u', 'n']
# 0 ad False
# 1 d False
# 46 as. ['a', 'z'] ad ['a', 'd']
# 0 ây False
# 1 y False
# 47 a ['eɪ'] ây ['â', 'y']
# 0 lo False
# 1 ot False
# 2 t False
# 48 lot ['l', 'ɒ', 't'] lot ['l', 'o', 't']
# 0 ov False
# 1 v False
# 49 of ['ɒ', 'v'] ov ['o', 'v']
# 0 pi False
# 1 ip False
# 2 pồ False
# 3 ồ False
# 50 people ['p', 'iː', 'p', 'əl'] pipồ ['p', 'i', 'p', 'ồ']
# 0 ha False
# 1 ađ False
# 2 đ False
# 51 had ['h', 'a', 'd'] hađ ['h', 'a', 'đ']
# 0 đe False
# 1 e False
# 52 their ['ð', 'eə'] đe ['đ', 'e']
# 0 ph True
# 2 ơs False
# 3 st False
# 4 t False
# 53 first ['f', 'ɜː', 's', 't'] phơst ['ph', 'ơ', 's', 't']
# 0 qu True
# 2 ic False
# 3 ci False
# 4 i False
# 54 wiki ['w', 'ɪ', 'k', 'i'] quici ['qu', 'i', 'c', 'i']
# 0 ec False
# 1 cs False
# 2 sp False
# 3 pi False
# 4 i  False
# 5  ơ False
# 6 ơr False
# 7 ri False
# 8 iơ False
# 9 ơn False
# 10 ns False
# 11 s False
# 55 experience ['ɛ', 'k', 's', 'p', 'iə', 'ɹ', 'ɪ', '', 'ə', 'n', 's'] ecspi ơriơns ['e', 'c', 's', 'p', 'i', ' ', 'ơ', 'r', 'i', 'ơ', 'n', 's']
# 0 hi False
# 1 i  False
# 2  ơ False
# 3 ơ False
# 56 here. ['h', 'iə'] hi ơ ['h', 'i', ' ', 'ơ']
# 0 đi False
# 1 is False
# 2 s False
# 57 this ['ð', 'ɪ', 's'] đis ['đ', 'i', 's']
# 0 cơ False
# 1 ơm False
# 2 md False
# 3 du False
# 4 un False
# 5 ni False
# 6 it False
# 7 ti False
# 8 i False
# 58 community ['k', 'ə', 'm', 'j', 'uː', 'n', 'ɪ', 't', 'i'] cơmduniti ['c', 'ơ', 'm', 'd', 'u', 'n', 'i', 't', 'i']
# 0 ha False
# 1 ad False
# 2 d False
# 59 has ['h', 'a', 'z'] had ['h', 'a', 'd']
# 0 bi False
# 1 in False
# 2 n False
# 60 been ['b', 'iː', 'n'] bin ['b', 'i', 'n']
# 0 ar False
# 1 ra False
# 2 ao False
# 3 on False
# 4 nđ False
# 5 đ False
# 61 around ['ɐ', 'ɹ', 'aʊ', 'n', 'd'] araonđ ['a', 'r', 'a', 'o', 'n', 'đ']
# 0 si False
# 1 in False
# 2 ns False
# 3 s False
# 62 since ['s', 'ɪ', 'n', 's'] sins ['s', 'i', 'n', 's']
# 0 na False
# 1 ai False
# 2 in False
# 3 nt False
# 4 ti False
# 5 in False
# 6 nh False
# 7 hâ False
# 8 ân False
# 9 nđ False
# 10 đr False
# 11 ri False
# 12 iđ False
# 13 đơ False
# 14 ơn False
# 15 n  False
# 16  n False
# 17 na False
# 18 ai False
# 19 in False
# 20 nt False
# 21 ti False
# 22 i  False
# 23  f False
# 24 fa False
# 25 ai False
# 26 iv False
# 27 v False
# 63 1995 ['n', 'aɪ', 'n', 't', 'iː', 'n', 'h', 'ʌ', 'n', 'd', 'ɹ', 'ɪ', 'd', 'ə', 'n n', 'aɪ', 'n', 't', 'i f', 'aɪ', 'v'] naintinhânđriđơn nainti faiv ['n', 'a', 'i', 'n', 't', 'i', 'n', 'h', 'â', 'n', 'đ', 'r', 'i', 'đ', 'ơ', 'n', ' ', 'n', 'a', 'i', 'n', 't', 'i', ' ', 'f', 'a', 'i', 'v']
# 0 an False
# 1 nđ False
# 2 đ False
# 64 and ['a', 'n', 'd'] anđ ['a', 'n', 'đ']
# 0 cơ False
# 1 ơn False
# 2 ns False
# 3 si False
# 4 is False
# 5 st False
# 6 ts False
# 7 s False
# 65 consists ['k', 'ə', 'n', 's', 'ɪ', 's', 't', 's'] cơnsists ['c', 'ơ', 'n', 's', 'i', 's', 't', 's']
# 0 ov False
# 1 v False
# 66 of ['ɒ', 'v'] ov ['o', 'v']
# 0 me False
# 1 en False
# 2 ni False
# 3 i False
# 67 many ['m', 'ɛ', 'n', 'i'] meni ['m', 'e', 'n', 'i']
# 0 pi False
# 1 ip False
# 2 pồ False
# 3 ồ False
# 68 people. ['p', 'iː', 'p', 'əl'] pipồ ['p', 'i', 'p', 'ồ']
# 0 qu True
# 2 i False
# 69 we ['w', 'iː'] qui ['qu', 'i']
# 0 ol False
# 1 lq False
# 2 qu True
# 4 ây False
# 5 yd False
# 6 d False
# 70 always ['ɔː', 'l', 'w', 'eɪ', 'z'] olquâyd ['o', 'l', 'qu', 'â', 'y', 'd']
# 0 ac False
# 1 cs False
# 2 se False
# 3 ep False
# 4 pt False
# 5 t False
# 71 accept ['ɐ', 'k', 's', 'ɛ', 'p', 't'] acsept ['a', 'c', 's', 'e', 'p', 't']
# 0 nd False
# 1 du False
# 2 uc False
# 3 câ False
# 4 âm False
# 5 mơ False
# 6 ơd False
# 7 d False
# 72 newcomers ['n', 'j', 'uː', 'k', 'ʌ', 'm', 'ə', 'z'] nducâmơd ['n', 'd', 'u', 'c', 'â', 'm', 'ơ', 'd']
# 0 qu True
# 2 iđ False
# 3 đ False
# 73 with ['w', 'ɪ', 'ð'] quiđ ['qu', 'i', 'đ']
# 0 va False
# 1 al False
# 2 ld False
# 3 du False
# 4 uơ False
# 5 ơb False
# 6 bồ False
# 7 ồ False
# 74 valuable ['v', 'a', 'l', 'j', 'uː', 'ə', 'b', 'əl'] valduơbồ ['v', 'a', 'l', 'd', 'u', 'ơ', 'b', 'ồ']
# 0 co False
# 1 on False
# 2 nt False
# 3 tr True
# 5 ib False
# 6 bd False
# 7 du False
# 8 us False
# 9 sơ False
# 10 ơn False
# 11 nd False
# 12 d False
# 75 contributions. ['k', 'ɒ', 'n', 't', 'ɹ', 'ɪ', 'b', 'j', 'uː', 'ʃ', 'ə', 'n', 'z'] contribdusơnd ['c', 'o', 'n', 'tr', 'i', 'b', 'd', 'u', 's', 'ơ', 'n', 'd']
# 0 ip False
# 1 ph True
# 76 if ['ɪ', 'f'] iph ['i', 'ph']
# 0 du False
# 1 u False
# 77 you ['j', 'uː'] du ['d', 'u']
# 0 ha False
# 1 av False
# 2 vơ False
# 3 ơn False
# 4 nt False
# 5 t False
# 78 haven't ['h', 'a', 'v', 'ə', 'n', 't'] havơnt ['h', 'a', 'v', 'ơ', 'n', 't']
# 0 du False
# 1 ud False
# 2 dđ False
# 3 đ False
# 79 used ['j', 'uː', 'z', 'd'] dudđ ['d', 'u', 'd', 'đ']
# 0 ây False
# 1 y False
# 80 a ['eɪ'] ây ['â', 'y']
# 0 qu True
# 2 ic False
# 3 ci False
# 4 i False
# 81 wiki ['w', 'ɪ', 'k', 'i'] quici ['qu', 'i', 'c', 'i']
# 0 bi False
# 1 ip False
# 2 ph True
# 4 o False
# 82 before, ['b', 'ɪ', 'f', 'ɔː'] bipho ['b', 'i', 'ph', 'o']
# 0 bi False
# 1 i False
# 83 be ['b', 'iː'] bi ['b', 'i']
# 0 pr False
# 1 ri False
# 2 ip False
# 3 pe False
# 4 eđ False
# 5 đ False
# 84 prepared ['p', 'ɹ', 'ɪ', 'p', 'eə', 'd'] pripeđ ['p', 'r', 'i', 'p', 'e', 'đ']
# 0 ph True
# 2 o False
# 85 for ['f', 'ɔː'] pho ['ph', 'o']
# 0 ây False
# 1 y False
# 86 a ['eɪ'] ây ['â', 'y']
# 0 bi False
# 1 it False
# 2 t False
# 87 bit ['b', 'ɪ', 't'] bit ['b', 'i', 't']
# 0 ov False
# 1 v False
# 88 of ['ɒ', 'v'] ov ['o', 'v']
# 0 câ False
# 1 âl False
# 2 lc False
# 3 ch True
# 5 ơr False
# 6 re False
# 7 es False
# 8 so False
# 9 oc False
# 10 c False
# 89 cultureshock. ['k', 'ʌ', 'l', 'tʃ', 'ə', 'ɹ', 'ɛ', 'ʃ', 'ɒ', 'k'] câlchơresoc ['c', 'â', 'l', 'ch', 'ơ', 'r', 'e', 's', 'o', 'c']
# 0 đơ False
# 1 ơ False
# 90 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 du False
# 1 us False
# 2 sp False
# 3 ph True
# 5 ồn False
# 6 nơ False
# 7 ơs False
# 8 s False
# 91 usefulness ['j', 'uː', 's', 'f', 'əl', 'n', 'ə', 's'] dusphồnơs ['d', 'u', 's', 'ph', 'ồ', 'n', 'ơ', 's']
# 0 ov False
# 1 v False
# 92 of ['ɒ', 'v'] ov ['o', 'v']
# 0 qu True
# 2 ic False
# 3 ci False
# 4 i False
# 93 wiki ['w', 'ɪ', 'k', 'i'] quici ['qu', 'i', 'c', 'i']
# 0 id False
# 1 d False
# 94 is ['ɪ', 'z'] id ['i', 'd']
# 0 in False
# 1 n False
# 95 in ['ɪ', 'n'] in ['i', 'n']
# 0 đơ False
# 1 ơ False
# 96 the ['ð', 'ə'] đơ ['đ', 'ơ']
# 0 ph True
# 2 ri False
# 3 iđ False
# 4 đơ False
# 5 ơm False
# 6 m False
# 97 freedom, ['f', 'ɹ', 'iː', 'd', 'ə', 'm'] phriđơm ['ph', 'r', 'i', 'đ', 'ơ', 'm']
# 0 si False
# 1 im False
# 2 mp False
# 3 pl False
# 4 li False
# 5 is False
# 6 si False
# 7 it False
# 8 ti False
# 9 i False
# 98 simplicity, ['s', 'ɪ', 'm', 'p', 'l', 'ɪ', 's', 'ɪ', 't', 'i'] simplisiti ['s', 'i', 'm', 'p', 'l', 'i', 's', 'i', 't', 'i']
# 0 an False
# 1 nđ False
# 2 đ False
# 99 and ['a', 'n', 'd'] anđ ['a', 'n', 'đ']
# 0 pa False
# 1 ao False
# 2 oơ False
# 3 ơ False
# 100 power ['p', 'aʊ', 'ə'] paoơ ['p', 'a', 'o', 'ơ']
# 0 it False
# 1 t False
# 101 it ['ɪ', 't'] it ['i', 't']
# 0 op False
# 1 ph True
# 3 ơd False
# 4 d False
# 102 offers ['ɒ', 'f', 'ə', 'z'] ophơd ['o', 'ph', 'ơ', 'd']

# %%
removed_pun_ipa_list = [712, 716]
# , 720]

# %%
def remove_spec_punc(word):
    ret_= []
    for i in result:
        tmp = ""
        for j in i:
            if ord(j) not in removed_pun_ipa_list:
                tmp += j
        ret_.append(tmp)
    return ret_

def mapping(word):
    ret_= []
    for w in word:
        ret_.append(map_dict[w] if w in map_dict else w)
    return ret_

# %%
word = "metal"
word = "lanɡquich"
cmd = "espeak {} --ipa=1".format(word)
result = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
result = result.stdout.read().decode('utf-8').split("\n")[0].split("_")
print(idx, word, result, remove_spec_punc(result), "".join([i for i in mapping(remove_spec_punc(result))]))
# Out:
# 102 lanɡquich ['ˈɛ', 'l ɐ ˈɛ', 'n l', 'ˌɛ', 't', 'ə', '', 't', 'ˈuː', '', 's', 'ˈɪ', 'k', 's', '', 'w', 'ˈɒ', 'n', ' k', 'j', 'ˈuː j', 'ˈuː ˈaɪ s', 'ˈiː', ' ˈeɪ', 'tʃ'] ['ɛ', 'l ɐ ɛ', 'n l', 'ɛ', 't', 'ə', '', 't', 'uː', '', 's', 'ɪ', 'k', 's', '', 'w', 'ɒ', 'n', ' k', 'j', 'uː j', 'uː aɪ s', 'iː', ' eɪ', 'tʃ'] el ɐ ɛn letơtusicsquon kduː juː aɪ si eɪch

# %%
viet_consonant_apha = [
 'b',
 'c',
 'd',
 'đ',
 'g',
 'h',
 'k',
 'l',
 'n',
 'p',
 'q',
 'r',
 's',
 't',
 'v',
 'x']

viet_vowel_alpha = ['a','ă', 'â', 'e', 'ê', 'o', 'ô', 'ơ', 'u', 'ư', 'i', 'y']

viet_compound_alpha = ['ch', 'gh', 'ph', 'tr', 'th', 'qu', 'kh', 'gi', 'ng', 'ng']

# %%
viet_compound_alpha
# Out:
# ['ch', 'gh', 'ph', 'tr', 'th', 'qu', 'kh', 'gi', 'ng', 'ng']

# %%
def ipa_to_viet(ipa_form):
    ret_= []
    current_idx = 0
    while current_idx < len(ipa_form):
        print(current_idx, ipa_form[current_idx:current_idx+2], ipa_form[current_idx:current_idx+2] in viet_compound_alpha)
        
        if ipa_form[current_idx:current_idx+2] in viet_compound_alpha:
            ret_.append(ipa_form[current_idx:current_idx+2])
            current_idx += 2
        else:
            ret_.append(ipa_form[current_idx])
            current_idx += 1
    return ret_

# %%
ipa_to_viet('lanɡquich')
# Out:
# 0 la False
# 1 an False
# 2 nɡ False
# 3 ɡq False
# 4 qu True
# 6 ic False
# 7 ch True
# ['l', 'a', 'n', 'ɡ', 'qu', 'i', 'ch']

# %%
'ng' in viet_compound_alpha
# Out:
# True

# %%
# http://www.antimoon.com/how/pronunc-soundsipa.htm
map_dict = {
    "iə": "i ơ",
    "ɐ": "a",
    "əʊ": "âu",
    "ʌ":    "â",
    "ɑː": "a",
    "ɑ":    "o",
    "æ":    "a",
    "e":    "e",
    "ə":    "ơ",
    "ɜ":    "ơ",
    "ɪ":    "i",
    "i":    "i",
    "ɒ":    "o",
    "ɔ":    "ô",
    "ʊ":    "u",
    "u":    "u",
    "aɪ":   "ai",
    "aʊ":   "ao",
    "eɪ":   "ây",
    "oʊ":   "âu", # go >< home
    "ɔɪ":   "oi",
    "eə":   "e",
    "ɪə":   "ia",
    "ʊə":   "ua",
    "b":    "b",
    "d":    "đ",
    "f":    "ph",
    "g":    "g",
    "h":    "h",
    "j":    "d",
    "k":    "c",
    "l":    "l",
    "m":    "m",
    "n":    "n",
    "ŋ":    "n",
    "p":    "p",
    "r":    "r",
    "s":    "s",
    "ʃ":    "s",
    "t":    "t",
    "tʃ":   "ch",
    "θ":    "th",
    "ð":    "đ",
    "v":    "v",
    "w":    "qu",
    "z":    "d",
    "ʒ":    "d",
    "dʒ":   "ch", 
    "ju":   "iu", # exception
    "ɔk":   "óc",
    "ɑʊ": "ao",
    "tɹ": "tr",
    "ɒs" : "ot",
    "ɪl": "iu", 
    "ɪv": "i",
    "əl": "ồ",
    "ɛ": "e",
    "ɹ" : "r",
    "ɜː": "ơ",
    "iː": "i",
    "uː": "u",
    "ɔː": "o"
}

# %% [markdown]
# ### Rules
#
# 1.

# %%
word = "metal"
word = "language"
cmd = "espeak {} --ipa=1".format(word)
result = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
result = result.stdout.read().decode('utf-8').split("\n")[0].split("_")
print(idx, word, result, remove_spec_punc(result), "".join([i for i in mapping(remove_spec_punc(result))]))
# Out:
# 0 language ['l', 'ˈa', 'ŋ', 'ɡ', 'w', 'ɪ', 'dʒ'] ['l', 'a', 'ŋ', 'ɡ', 'w', 'ɪ', 'dʒ'] lanɡquich

# %%
def is_consonant(char):
    if char in viet_consonant_apha:
        return True
    else:
        return False

def is_vowel(char):
    if char in viet_vowel_alpha:
        return True
    else:
        return False

# %%
def ipa_to_viet(ipa_form):
    ret_= []
    curren_idx = 0
    while curren_idx < len(ipa_form):
        if ipa_form[curren_idx:curren_idx+2] in viet_compound_alpha:
            ret_.append(ipa_form[curren_idx:curren_idx+2])
            curren_idx += 2
        elif ipa_form[curren_idx] in map_dict:
            ret_.append(ipa_form[curren_idx:curren_idx+1])
            curren_idx += 1
        else:
            ret_.append(ipa_form[curren_idx:curren_idx])
            curren_idx += 1
    return ret_
